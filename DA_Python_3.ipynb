# %% [markdown]
# <a href="https://colab.research.google.com/github/Praneeth9630/Data-Science-and-AI/blob/main/DA_Python_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Input**
# - want to take input from the user, In python we have the input() function
# - by default it takes as "str" data type

# %%
a = input()
# Out:
# praneeth

# %%
type(a)
# Out:
# str

# %%
a = input("Enter your age: ")
# Out:
# Enter your age: 21

# %%
s = input("Enter your age: ")
print("The entered value:",s)
print("The data type of entered value",type(s))
# Out:
# Enter your age: 21
# The entered value: 21
# The data type of entered value <class 'str'>

# %%
m = int(input("Enter your age: "))
print("The entered value:",m)
print("The data type of entered value",type(m))
# Out:
# Enter your age: 21
# The entered value: 21
# The data type of entered value <class 'int'>

# %%
m = float(input("Enter your age: "))
print("The entered value:",m)
print("The data type of entered value",type(m))
# Out:
# Enter your age: 21
# The entered value: 21.0
# The data type of entered value <class 'float'>

# %%
name = input("What is your name? ")
age = int(input("Enter your age? "))
print("It was nice talking to you", name, "!")
print("Hey, you are already", age, "years old,", name, "!")
# Out:
# What is your name? praneeth
# Enter your age? 21
# It was nice talking to you praneeth !
# Hey, you are already 21 years old, praneeth !

# %% [markdown]
# # **Indexing (accessing characters in a string)**
# - Strings can be indexed - often synonymously called subscripted as well.
# - Python Supports both +ve index & -ve index
#   - +ve index means left to right (forward direction) -> Forward Indexing
#   - -ve index means right to left (backward direction) -> Reverse indexing
# - The first character of a string has the index 0.

# %% [markdown]
# ![indexing1.png](data:image/png;base64,...)

# %%
s = "Data science"

# %% [markdown]
# ![indexing2.png](data:image/png;base64,...)

# %%
len(s)
# Out:
# 12

# %%
s[0]                # Variablename[index_number]
# Out:
# 'D'

# %%
s[11]
# Out:
# 'e'

# %%
s[-1]
# Out:
# 'e'

# %%
s[-12]
# Out:
# 'D'

# %%
s[12]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-ccbc0585b80d> in <cell line: 1>()
# ----> 1 s[12]
#
# IndexError: string index out of range

# %%
s[1.5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-9c4337c72b36> in <cell line: 1>()
# ----> 1 s[1.5]
#
# TypeError: string indices must be integers

# %% [markdown]
# # **Slicing the strings**
# - start index (inclusive): end index (exclusive): step
# - Step can be either +ve or -ve & default value = +1

# %% [markdown]
# ![slicing2.png](data:image/png;base64,...)

# %%
s[0:10:1]
# Out:
# 'Data scien'

# %%
s[0:10:2]
# Out:
# 'Dt ce'

# %%
s[0:10:4]
# Out:
# 'D e'

# %%
s[0:10:-1]
# Out:
# ''

# %%
s[-10:-6:1]
# Out:
# 'ta s'

# %%
s[15:20:1]
# Out:
# ''

# %%
s[8:15:1]
# Out:
# 'ence'

# %%
s[15:8:-1]
# Out:
# 'ecn'

# %%
s[5:12:1]
# Out:
# 'science'

# %%
s[:5:1]
# Out:
# 'Data '

# %%
s[:5:-1]
# Out:
# 'ecneic'

# %%
s[1::1]
# Out:
# 'ata science'

# %%
s[1::-1]
# Out:
# 'aD'

# %%
s[1:5]
# Out:
# 'ata '

# %%
s[:5]
# Out:
# 'Data '

# %%
s[::-1]
# Out:
# 'ecneics ataD'

# %%
s[::]
# Out:
# 'Data science'

# %%
s[0:-3]
# Out:
# 'Data scie'
