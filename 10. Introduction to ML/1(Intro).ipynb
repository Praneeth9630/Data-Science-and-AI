# %% [markdown]
# # Structured Data
#   - Cross Sectional Data
#
#       - Continous
#
#       - Discrete
#
#   - Time Series Data
#
# **DA : Descriptive Analytics on Structured Data**
#
# Describing the past data
#
# Ex: D-Mart
#
# **ML : Predictive Analytics on Structured Data**
#
# Predictive Analytics on Cross Sectional Data -- > Supervised ML & unsupervised ML
#
# Predictive Analytics on Time Series Data --- > Forecasting (Time Series Analysis)

# %% [markdown]
# # Labelled Data : input & output -- > relation b/w i/p & o/p
#
# **Machine Learning Techniques applied on Labelled Data : Supervised ML Techniques**
#
# - **Regression** : predicting o/p variable which is continous
#
#       Ex: Data Scienctist Salary
#
#           House Price Prediction
#
#           Sales
#
#
# - **Classification** : predicting o/p variable which is discrete
#
#      Ex: diabetic (yes,no)
#
#          stroke(yes,no)
#
#
#
#
#
# covid : prevention

# %% [markdown]
# # UnLabled Data : Input    --> Predict
# **Machine Learning Techniques applied on UnLabelled Data : UnSupervised ML Techniques**
#
# - **Clustering** : Grouping of similar records
#
#       Ex: Covid
#
# - **Association Rules** : Most repeated combination
#
#      Ex: DMart, Amazon, Flipkart
#
# - **Recommendation Engines**
#
#      Ex: Youtube

# %% [markdown]
# ![image.png](attachment:aae19846-5d3f-486f-a2eb-1c8099ba8e97.png)

# %% [markdown]
# # Steps involved in Regression Project
#
# Development phase
# -----------------
# 1. **Business Problem Understanding**
#
# 2. **Data Understanding**
#
#     -- > load the data
#
#     -- > data understanding : understand each & every column name
#
#     -- > Data Exploration
#
# 3. **Data Preprocessing**
#
#     -- > Data Cleaning
#
#     -- > Data Wrangling
#
#     -- > Feature Engineering : Add the new columns as per requirements
#
#     -- > Dimension Reduction : reducing no.of input features
#
#            -- > Feature Selection
#                   -- Filter Methods
#
#                   -- Wrapper Methods
#
#                   -- Embedded Methods
#
#            -- > Feature Extraction (PCA)
# 4. **Modelling** : Apply ML Algorithms & Identify the relation between i/p & o/p
#
# 5. **Evaluation**   : Error for Regression Projects
#
#                 : Accuracy for Classification Projects
#
#
# 7. **Model Selection** : whether ur model is good or bad
#
# 8. Save the best Model which has highest accuracy
#
# Operation Phase
# ----------------------------------
#
# 8. **Deployment  :  Usage of model in real life**
#
#    Data is divided into 2 parts
#
#                Train Data : Modelling & evaluation are done on train data
#
#                Test Data : Evaluation is done on test data
#    Modelling : apply ML algorithm -- > Identify the relation/equation (Model)
#
#    Evaluation:
#    train data : what Im explaining the class (notes)
#
#    your brain : Modelling (learning : understanding the train data)
#
#    test in class what i explained based on train data : some questions asking
#
#                                                          -- > your answers (prediction)
#
#                                                          -- > comparing yor answers with original answers (marks: accuracy)
#    train accuracy
#
#    Test on new data (which is completely unknown to your brain) I
#
#    questions --- > your answers (prediction)
#
#                --- > compare your answers with original answers (test accuracy)
