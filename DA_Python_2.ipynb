# %% [markdown]
# <a href="https://colab.research.google.com/github/Praneeth9630/Data-Science-and-AI/blob/main/DA_Python_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Integer**
# - Numerical value with no decimal
# - Can be either negative or positive or zero

# %%
a = 10

# %%
print(a)
# Out:
# 10

# %%
type(a)                      #To check data type use type() function
# Out:
# int

# %%
id(a)                        # Address of the object
# Out:
# 138798588985872

# %% [markdown]
# # **Float**
# - Numerical value with decimal

# %%
b = 1.55

# %%
print(b)
# Out:
# 1.55

# %%
type(b)
# Out:
# float

# %% [markdown]
# # **Boolean(bool)**
# - True/False

# %%
c = False
print(c)
# Out:
# False

# %%
type(c)
# Out:
# bool

# %% [markdown]
# # **String**
# - a combination or sequence of characters(alphabets,numbers,special characters)
# - We can use single quotes or double quotes to represent strings

# %%
string1 = 'hello'
print(string1)
# Out:
# hello

# %%
string2 = "hello"
print(string2)
# Out:
# hello

# %% [markdown]
# **Multi-line strings can denoted by using   ''' or '''**

# %%
name = ''' data
           science'''
print(name)
# Out:
#  data
# science

# %%
var1 = 123
type(var1)
# Out:
# int

# %%
var2 = "123"
type(var2)
# Out:
# str

# %% [markdown]
# **Length of a string**

# %%
string3 = "praneeth"

len(string3)
# Out:
# 8

# %%
a = 1234
len(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-665e6f1289e3> in <cell line: 2>()
#       1 a = 1234
# ----> 2 len(a)
#
# TypeError: object of type 'int' has no len()

# %% [markdown]
# ![Type casting.png](data:image/png;base64,...)

# %% [markdown]
# ![type casting 2.png](data:image/png;base64,...)

# %%
#int
a = 12

# %%
#int -- float
float(a)
# Out:
# 12.0

# %%
#int -- bool
bool(a)                           # ANy value other than zero will give True
# Out:
# True

# %%
#int -- string
str(a)
# Out:
# '12'

# %% [markdown]
# Explore the int conversion with negativa value and zero also

# %%
#float
b = 10.7

# %%
#float -- int
int(b)
# Out:
# 10

# %%
round(b)
# Out:
# 11

# %%
#float -- bool
bool(b)
# Out:
# True

# %%
#float -- string
str(b)
# Out:
# '10.7'

# %%
#bool -- int
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
#bool -- float
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
#bool -- string
str(True)
# Out:
# 'True'

# %%
str(False)
# Out:
# 'False'

# %%
#string
s = "123"
s1 = "praneeth123"

# %% [markdown]
# ![string1.png](data:image/png;base64,...)

# %%
#string -- int
int(s1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-eae4e6c1ae07> in <cell line: 2>()
#       1 #string -- int
# ----> 2 int(s1)
#
# ValueError: invalid literal for int() with base 10: 'praneeth123'

# %%
#string -- int
int(s)
# Out:
# 123

# %%
#string -- float
float(s)
# Out:
# 123.0

# %%
#string -- bool
bool(s)
# Out:
# True

# %% [markdown]
# When there are multiple brackets the code execution starts at the inner most one then exceutes to the outermost one - this is called functional programming

# %%
float(12.34)
# Out:
# 12.34

# %%
str(bool(float(12.34)))
# Out:
# 'True'

# %%
a = 14
bool(str(float(bool(a))))
# Out:
# True
