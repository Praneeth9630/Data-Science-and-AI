# %% [markdown]
# ![image.png](attachment:906ecf9d-f672-4071-aef6-612c90199431.png)

# %% [markdown]
# ![image.png](attachment:8975e4f6-9637-4bc4-9c31-148cb7e5636f.png)

# %% [markdown]
# ![image.png](attachment:2007aeb6-d924-4961-90e1-b44abc5759ac.png)

# %% [markdown]
# ![image.png](attachment:c47c1220-e320-4204-a024-772377c4e54f.png)

# %% [markdown]
# ![image.png](attachment:40b8982d-3ab8-42d8-988f-24e344bcf136.png)

# %% [markdown]
# ![image.png](attachment:e40e95b3-f4e1-462a-837b-73fafe3fd116.png)
