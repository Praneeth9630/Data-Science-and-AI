# 116  15-09-1958         404
# 117  15-10-1958         359
# 118  15-11-1958         310
# 119  15-12-1958         337
# 120  15-01-1959         360
# 121  15-02-1959         342
# 122  15-03-1959         406
# 123  15-04-1959         396
# 124  15-05-1959         420
# 125  15-06-1959         472
# 126  15-07-1959         548
# 127  15-08-1959         559
# 128  15-09-1959         463
# 129  15-10-1959         407
# 130  15-11-1959         362
# 131  15-12-1959         405
# 132  15-01-1960         417
# 133  15-02-1960         391
# 134  15-03-1960         419
# 135  15-04-1960         461
# 136  15-05-1960         472
# 137  15-06-1960         535
# 138  15-07-1960         622
# 139  15-08-1960         606
# 140  15-09-1960         508
# 141  15-10-1960         461
# 142  15-11-1960         390
# 143  15-12-1960         432

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Month       144 non-null    object
#  1   Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
df = df.set_index('Month')

# %% [markdown]
# # Visualize the time series
#
# - Check for trend, seasonality or random patterns

# %%
sns.lineplot(x=df.index, y=df ['Passengers'])
plt.show()

# %% [markdown]
# # **Step-3: Data Preprocessing**
#
# **Check for stationarity**
#
# **Method-1: Rolling Statistics**

# %%
rolmean = df['Passengers'].rolling(window=12).mean()
rolmean
# Out:
# Month
# 15-01-1949           NaN
# 15-02-1949           NaN
# 15-03-1949           NaN
# 15-04-1949           NaN
# 15-05-1949           NaN
# 15-06-1949           NaN
# 15-07-1949           NaN
# 15-08-1949           NaN
# 15-09-1949           NaN
# 15-10-1949           NaN
# 15-11-1949           NaN
# 15-12-1949    126.666667
# 15-01-1950    126.916667
# 15-02-1950    127.583333
# 15-03-1950    128.333333
# 15-04-1950    128.833333
# 15-05-1950    129.166667
# 15-06-1950    130.333333
# 15-07-1950    132.166667
# 15-08-1950    134.000000
# 15-09-1950    135.833333
# 15-10-1950    137.000000
# 15-11-1950    137.833333
# 15-12-1950    139.666667
# 15-01-1951    142.166667
# 15-02-1951    144.166667
# 15-03-1951    147.250000
# 15-04-1951    149.583333
# 15-05-1951    153.500000
# 15-06-1951    155.916667
# 15-07-1951    158.333333
# 15-08-1951    160.750000
# 15-09-1951    162.916667
# 15-10-1951    165.333333
# 15-11-1951    168.000000
# 15-12-1951    170.166667
# 15-01-1952    172.333333
# 15-02-1952    174.833333
# 15-03-1952    176.083333
# 15-04-1952    177.583333
# 15-05-1952    178.500000
# 15-06-1952    181.833333
# 15-07-1952    184.416667
# 15-08-1952    188.000000
# 15-09-1952    190.083333
# 15-10-1952    192.500000
# 15-11-1952    194.666667
# 15-12-1952    197.000000
# 15-01-1953    199.083333
# 15-02-1953    200.416667
# 15-03-1953    204.000000
# 15-04-1953    208.500000
# 15-05-1953    212.333333
# 15-06-1953    214.416667
# 15-07-1953    217.250000
# 15-08-1953    219.750000
# 15-09-1953    222.083333
# 15-10-1953    223.750000
# 15-11-1953    224.416667
# 15-12-1953    225.000000
# 15-01-1954    225.666667
# 15-02-1954    225.000000
# 15-03-1954    224.916667
# 15-04-1954    224.250000
# 15-05-1954    224.666667
# 15-06-1954    226.416667
# 15-07-1954    229.583333
# 15-08-1954    231.333333
# 15-09-1954    233.166667
# 15-10-1954    234.666667
# 15-11-1954    236.583333
# 15-12-1954    238.916667
# 15-01-1955    242.083333
# 15-02-1955    245.833333
# 15-03-1955    248.500000
# 15-04-1955    252.000000
# 15-05-1955    255.000000
# 15-06-1955    259.250000
# 15-07-1955    264.416667
# 15-08-1955    268.916667
# 15-09-1955    273.333333
# 15-10-1955    277.083333
# 15-11-1955    279.916667
# 15-12-1955    284.000000
# 15-01-1956    287.500000
# 15-02-1956    291.166667
# 15-03-1956    295.333333
# 15-04-1956    299.000000
# 15-05-1956    303.000000
# 15-06-1956    307.916667
# 15-07-1956    312.000000
# 15-08-1956    316.833333
# 15-09-1956    320.416667
# 15-10-1956    323.083333
# 15-11-1956    325.916667
# 15-12-1956    328.250000
# 15-01-1957    330.833333
# 15-02-1957    332.833333
# 15-03-1957    336.083333
# 15-04-1957    339.000000
# 15-05-1957    342.083333
# 15-06-1957    346.083333
# 15-07-1957    350.416667
# 15-08-1957    355.583333
# 15-09-1957    359.666667
# 15-10-1957    363.083333
# 15-11-1957    365.916667
# 15-12-1957    368.416667
# 15-01-1958    370.500000
# 15-02-1958    371.916667
# 15-03-1958    372.416667
# 15-04-1958    372.416667
# 15-05-1958    373.083333
# 15-06-1958    374.166667
# 15-07-1958    376.333333
# 15-08-1958    379.500000
# 15-09-1958    379.500000
# 15-10-1958    380.500000
# 15-11-1958    380.916667
# 15-12-1958    381.000000
# 15-01-1959    382.666667
# 15-02-1959    384.666667
# 15-03-1959    388.333333
# 15-04-1959    392.333333
# 15-05-1959    397.083333
# 15-06-1959    400.166667
# 15-07-1959    404.916667
# 15-08-1959    409.416667
# 15-09-1959    414.333333
# 15-10-1959    418.333333
# 15-11-1959    422.666667
# 15-12-1959    428.333333
# 15-01-1960    433.083333
# 15-02-1960    437.166667
# 15-03-1960    438.250000
# 15-04-1960    443.666667
# 15-05-1960    448.000000
# 15-06-1960    453.250000
# 15-07-1960    459.416667
# 15-08-1960    463.333333
# 15-09-1960    467.083333
# 15-10-1960    471.583333
# 15-11-1960    473.916667
# 15-12-1960    476.166667
# Name: Passengers, dtype: float64

# %%
#Determing rolling statistics
rolmean = df['Passengers'].rolling(window=12).mean()
rolstd = df['Passengers'].rolling(window=12).std()

#PLot rolling statistics:
orig = plt.plot(df['Passengers'], color='blue',label='Original')
mean = plt.plot(rolmean, color='red', label='Rolling Mean')
std = plt.plot(rolstd, color='black', label = 'Rolling Std')
plt.title('Rolling Mean & Standard Deviation')
plt.xticks(ticks=df.index)
plt.legend()
plt.show()

# %% [markdown]
# **Method 2: Augmented Dicky Fuller Test**
#
# - For the ADF Test
#
#       -> HO: data is non-stationary
#       -> H1: data is stationary
#
# - Based on pvalue, we will accept or reject HO (if p-value < 5% reject null hypothesis)

# %%
from statsmodels.tsa.stattools import adfuller

adfuller_result = adfuller(df['Passengers'])
print('p-value:', adfuller_result[1])
# Out:
# p-value: 0.9918802434376411

# %% [markdown]
# - As p>0.05 --> P high , Null fly so
# - **The time series is non stationary**

# %% [markdown]
# # Now, we have to convert the non-stationary data to stationary data
#
# **Differencing**

# 15-05-1958     15.0
# 15-06-1958     72.0
# 15-07-1958     56.0
# 15-08-1958     14.0
# 15-09-1958   -101.0
# 15-10-1958    -45.0
# 15-11-1958    -49.0
# 15-12-1958     27.0
# 15-01-1959     23.0
# 15-02-1959    -18.0
# 15-03-1959     64.0
# 15-04-1959    -10.0
# 15-05-1959     24.0
# 15-06-1959     52.0
# 15-07-1959     76.0
# 15-08-1959     11.0
# 15-09-1959    -96.0
# 15-10-1959    -56.0
# 15-11-1959    -45.0
# 15-12-1959     43.0
# 15-01-1960     12.0
# 15-02-1960    -26.0
# 15-03-1960     28.0
# 15-04-1960     42.0
# 15-05-1960     11.0
# 15-06-1960     63.0
# 15-07-1960     87.0
# 15-08-1960    -16.0
# 15-09-1960    -98.0
# 15-10-1960    -47.0
# 15-11-1960    -71.0
# 15-12-1960     42.0
# Name: Passengers, dtype: float64

# %%
# apply differencing
diff = df['Passengers']- df['Passengers' ].shift(1)

diff.dropna(inplace=True)

# check whether the data is stationary or not after applying differencing
adfuller_result = adfuller(diff)
print('p-value of adf test:', adfuller_result[1])
# Out:
# p-value of adf test: 0.05421329028382491

# %%
# apply differencing
diff = df['Passengers']- df ['Passengers'].shift(2)
diff
# Out:
# Month
# 15-01-1949      NaN
# 15-02-1949      NaN
# 15-03-1949     20.0
# 15-04-1949     11.0
# 15-05-1949    -11.0
# 15-06-1949      6.0
# 15-07-1949     27.0
# 15-08-1949     13.0
# 15-09-1949    -12.0
# 15-10-1949    -29.0
# 15-11-1949    -32.0
# 15-12-1949     -1.0
# 15-01-1950     11.0
# 15-02-1950      8.0
# 15-03-1950     26.0
# 15-04-1950      9.0
# 15-05-1950    -16.0
# 15-06-1950     14.0
# 15-07-1950     45.0
# 15-08-1950     21.0
# 15-09-1950    -12.0
# 15-10-1950    -37.0
# 15-11-1950    -44.0
# 15-12-1950      7.0
# 15-01-1951     31.0
# 15-02-1951     10.0
# 15-03-1951     33.0
# 15-04-1951     13.0
# 15-05-1951     -6.0
# 15-06-1951     15.0
# 15-07-1951     27.0
# 15-08-1951     21.0
# 15-09-1951    -15.0
# 15-10-1951    -37.0
# 15-11-1951    -38.0
# 15-12-1951      4.0
# 15-01-1952     25.0
# 15-02-1952     14.0
# 15-03-1952     22.0
# 15-04-1952      1.0
# 15-05-1952    -10.0
# 15-06-1952     37.0
# 15-07-1952     47.0
# 15-08-1952     24.0
# 15-09-1952    -21.0
# 15-10-1952    -51.0
# 15-11-1952    -37.0
# 15-12-1952      3.0
# 15-01-1953     24.0
# 15-02-1953      2.0
# 15-03-1953     40.0
# 15-04-1953     39.0
# 15-05-1953     -7.0
# 15-06-1953      8.0
# 15-07-1953     35.0
# 15-08-1953     29.0
# 15-09-1953    -27.0
# 15-10-1953    -61.0
# 15-11-1953    -57.0
# 15-12-1953    -10.0
# 15-01-1954     24.0
# 15-02-1954    -13.0
# 15-03-1954     31.0
# 15-04-1954     39.0
# 15-05-1954     -1.0
# 15-06-1954     37.0
# 15-07-1954     68.0
# 15-08-1954     29.0
# 15-09-1954    -43.0
# 15-10-1954    -64.0
# 15-11-1954    -56.0
# 15-12-1954      0.0
# 15-01-1955     39.0
# 15-02-1955      4.0
# 15-03-1955     25.0
# 15-04-1955     36.0
# 15-05-1955      3.0
# 15-06-1955     46.0
# 15-07-1955     94.0
# 15-08-1955     32.0
# 15-09-1955    -52.0
# 15-10-1955    -73.0
# 15-11-1955    -75.0
# 15-12-1955      4.0
# 15-01-1956     47.0
# 15-02-1956     -1.0
# 15-03-1956     33.0
# 15-04-1956     36.0
# 15-05-1956      1.0
# 15-06-1956     61.0
# 15-07-1956     95.0
# 15-08-1956     31.0
# 15-09-1956    -58.0
# 15-10-1956    -99.0
# 15-11-1956    -84.0
# 15-12-1956      0.0
# 15-01-1957     44.0
# 15-02-1957     -5.0
# 15-03-1957     41.0
# 15-04-1957     47.0
# 15-05-1957     -1.0
# 15-06-1957     74.0
# 15-07-1957    110.0
# 15-08-1957     45.0
# 15-09-1957    -61.0
# 15-10-1957   -120.0
# 15-11-1957    -99.0
# 15-12-1957    -11.0
# 15-01-1958     35.0
# 15-02-1958    -18.0
# 15-03-1958     22.0
# 15-04-1958     30.0
# 15-05-1958      1.0
# 15-06-1958     87.0
# 15-07-1958    128.0
# 15-08-1958     70.0
# 15-09-1958    -87.0
# 15-10-1958   -146.0
# 15-11-1958    -94.0
# 15-12-1958    -22.0
# 15-01-1959     50.0
# 15-02-1959      5.0
# 15-03-1959     46.0
# 15-04-1959     54.0
# 15-05-1959     14.0
# 15-06-1959     76.0
# 15-07-1959    128.0
# 15-08-1959     87.0
# 15-09-1959    -85.0
# 15-10-1959   -152.0
# 15-11-1959   -101.0
# 15-12-1959     -2.0
# 15-01-1960     55.0
# 15-02-1960    -14.0
# 15-03-1960      2.0
# 15-04-1960     70.0
# 15-05-1960     53.0
# 15-06-1960     74.0
# 15-07-1960    150.0
# 15-08-1960     71.0
# 15-09-1960   -114.0
# 15-10-1960   -145.0
# 15-11-1960   -118.0
# 15-12-1960    -29.0
# Name: Passengers, dtype: float64

# %%
# apply differencing
diff = df['Passengers']- df['Passengers' ].shift(2)

diff.dropna(inplace=True)

# check whether the data is stationary or not after applying differencing
adfuller_result = adfuller(diff)
print('p-value of adf test:', adfuller_result[1])
# Out:
# p-value of adf test: 0.03862975767698775

# %% [markdown]
# **Now, the time series is stationary.**

# %% [markdown]
# ![image.png](attachment:49c9d450-7dbb-4f1f-aca0-dae89faa8b7a.png)

# %% [markdown]
# # Train-test Split
# **Split the data into train (80%) & test(20%)**
#
# - for time series data, we have use first 80% of records for training & next 20% of records for testing
# - here 80% = 0.8*142 = 114 records, so first 114 records we have to use for training
#
# **Note: We should not apply train-test split function, because it divides the data randomly.**

# %%
y_train = diff[0:114]

y_test = diff[114:]

# %% [markdown]
# ![image.png](attachment:3537cab2-9f1c-4682-99dd-be630e0b2e5b.png)

# %% [markdown]
# ![image.png](attachment:c4d51f6c-db39-40a6-9435-f508bde8429b.png)

# %% [markdown]
# # Build ARIMA Model
# **ARIMA Model is build by using p,d,q values**
#
# - p is AR value (determined from PACF plot)
# - d is intergration
# - q is MA value (determined from ACF plot)
#
# **Plot ACF/PACF and find p & q parameters**
#
# - **Auto Correlation Function (ACF)** - A function which gives us values of auto-correlation of any series with its lagged values.
# - **Partial Auto Correlation Function (PACF)** - An indirect function to find Auto correlation after removing the relationship explained by previous lags
#
# **Time series lag example**
#
# - Original time series = {21,22,21,20,19}
# - Lagged time series by 1 lag = {22,21,20,19}
# - Lag 1 correlation will be correlation between {21,22,21,20} and {22,21,20,19}

# %%
from statsmodels.tsa.stattools import acf, pacf
import statsmodels.api as sm
fig = sm.graphics.tsa.plot_acf(diff,lags=30)
fig = sm.graphics.tsa.plot_pacf(diff,lags=30)

# %% [markdown]
# **From PACF curve, optimal value of p value (AR Model) is 11**
#
# **From ACF curve, optimal value of q value (MA model) must be 12 --> From first graph**

# %% [markdown]
# # ARIMA
#
# **ARIMA Model is build by using p,d,q values**
#
# - p is AR value (determined from PACF plot)
# - d is intergration
# - q is MA value (determined from ACF plot)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#AR Modelling (p)
from statsmodels.tsa. arima.model import ARIMA
model = ARIMA(diff, order=(11,0,0))
ARIMA = model.fit()

#Prediction & Evaluation on train data
ypred_train = ARIMA.predict(start=y_train.index[0], end=y_train. index[-1])

from sklearn.metrics import r2_score
print("Train R2 of AR Model:",r2_score(ypred_train,y_train))

#Prediction & Evaluation on test data
ypred_test = ARIMA.predict(start=y_test.index[0], end=y_test.index[-1])
print("Test R2 of AR Model:",r2_score(ypred_test,y_test))
# Out:
# Train R2 of AR Model: 0.9354945375501107
# Test R2 of AR Model: 0.9551178155890222

# %%
#MA Modelling (q)
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(diff, order=(0,0,12))
ARIMA = model.fit()

#Prediction & Evaluation on train data
ypred_train = ARIMA. predict(start=y_train.index[0], end=y_train.index[-1])

from sklearn.metrics import r2_score
print("Train R2 of MA Model:", r2_score(ypred_train, y_train))

#Prediction & Evaluation on test data
ypred_test = ARIMA.predict(start=y_test.index[0], end=y_test.index[-1])
print("Test R2 of MA Model:",r2_score(ypred_test,y_test))
# Out:
# Train R2 of MA Model: 0.8396330247226513
# Test R2 of MA Model: 0.8991167302402086

# %%
# ARMA (p,q) Modelling
from statsmodels.tsa. arima.model import ARIMA
model = ARIMA(diff, order=(11,0,12))
ARIMA = model.fit()

#Prediction & Evaluation on train data
ypred_train = ARIMA.predict(start=y_train. index[0], end=y_train.index[-1])

from sklearn.metrics import r2_score
print("Train R2 of ARMA Model:", r2_score(ypred_train,y_train))

#Prediction & Evaluation on test data
ypred_test = ARIMA.predict(start=y_test.index[0], end=y_test.index[-1])
print("Test R2 of ARMA Model:", r2_score(ypred_test,y_test))
# Out:
# Train R2 of ARMA Model: 0.9381790081151107
# Test R2 of ARMA Model: 0.9658009073380179

# %%
#ARIMA (p,d,q) Modelling
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(diff, order=(11,1,12))
ARIMA = model.fit()

#Prediction & Evaluation on train data
ypred_train = ARIMA.predict(start=y_train.index[0], end=y_train.index[-1])

from sklearn.metrics import r2_score
print("Train R2 of ARIMA Model:",r2_score(ypred_train,y_train))

#Prediction & Evaluation on test data
ypred_test = ARIMA.predict(start=y_test.index[0], end=y_test.index[-1])
print("Test R2 of ARIMA Model:",r2_score(ypred_test,y_test))
# Out:
# Train R2 of ARIMA Model: 0.9286657874333621
# Test R2 of ARIMA Model: 0.9641338929795981

# %%
#ARIMA (p,d,q) Modelling
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(diff, order=(11,2,12))                 # For d = 2
ARIMA = model.fit()

#Prediction & Evaluation on train data
ypred_train = ARIMA.predict(start=y_train.index[0], end=y_train.index[-1])

from sklearn.metrics import r2_score
print("Train R2 of ARIMA Model:",r2_score(ypred_train,y_train))

#Prediction & Evaluation on test data
ypred_test = ARIMA.predict(start=y_test.index[0], end=y_test.index[-1])
print("Test R2 of ARIMA Model:",r2_score(ypred_test,y_test))
# Out:
# Train R2 of ARIMA Model: 0.9192410567505058
# Test R2 of ARIMA Model: 0.9580159763188248

# %%
#ARIMA (p,d,q) Modelling
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(diff, order=(11,3,12))                 # For d = 3
ARIMA = model.fit()

#Prediction & Evaluation on train data
ypred_train = ARIMA.predict(start=y_train.index[0], end=y_train.index[-1])

from sklearn.metrics import r2_score
print("Train R2 of ARIMA Model:",r2_score(ypred_train,y_train))

#Prediction & Evaluation on test data
ypred_test = ARIMA.predict(start=y_test.index[0], end=y_test.index[-1])
print("Test R2 of ARIMA Model:",r2_score(ypred_test,y_test))
# Out:
# Train R2 of ARIMA Model: 0.8886664670850972
# Test R2 of ARIMA Model: 0.9422965554601516

# %%
#ARIMA (p,d,q) Modelling
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(diff, order=(11,4,12))                 # For d = 4
ARIMA = model.fit()

#Prediction & Evaluation on train data
ypred_train = ARIMA.predict(start=y_train.index[0], end=y_train.index[-1])

from sklearn.metrics import r2_score
print("Train R2 of ARIMA Model:",r2_score(ypred_train,y_train))

#Prediction & Evaluation on test data
ypred_test = ARIMA.predict(start=y_test.index[0], end=y_test.index[-1])
print("Test R2 of ARIMA Model:",r2_score(ypred_test,y_test))
# Out:
# Train R2 of ARIMA Model: 0.8259992866892119
# Test R2 of ARIMA Model: 0.9409410375162182

# %% [markdown]
# - From d = 4 we have overfitting problem

# %% [markdown]
# # Build SARIMAX Model
#
# **Whenever, there is seasonality in given data, apply SARIMAX**
#
# **SARIMAX Model is build by using p,d,q,s values**
#
# - p is AR value (determined from PACF plot)
# - d is intergration
# - q is MA value (determined from ACF plot)
# - s is seasonality value (determined from line plot)

# %%
##ModelLing
from statsmodels.tsa.statespace.sarimax import SARIMAX
model = SARIMAX(diff, seasonal_order=(11,1,12,12))
SARIMAX = model.fit() 

#Prediction
ypred_train = SARIMAX.predict(start=y_train.index[0], end=y_train.index[-1])
ypred_test = SARIMAX.predict(start=y_test.index[0], end=y_test.index[-1])

#Evaluation
print("Train R2 of SARIMAX model:",r2_score(ypred_train,y_train))
print("Test R2 of SARIMAX model:",r2_score(ypred_test,y_test))
# Out:
# Train R2 of SARIMAX model: 0.9021355428038431
# Test R2 of SARIMAX model: 0.9562824199420396
