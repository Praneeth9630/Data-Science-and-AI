# %% [markdown]
# <a href="https://colab.research.google.com/github/Praneeth9630/Data-Science-and-AI/blob/main/DA_Python_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - loop: repeat the block of code
# - while: till condition satisfies
# - while loop: till condition satisfies, repeat the block of code

# %%
x =1

if x<5:
  print("python")
  x = x+1
# Out:
# python

# %%
x =1

while x<5:
  print("python")
  x = x+1
# Out:
# python
# python
# python
# python

# %%
print("DS")
print("DS")
print("DS")
print("DS")
print("DS")
# Out:
# DS
# DS
# DS
# DS
# DS

# %%
x =1

while x<6:
  print("DS")
  x = x+1
# Out:
# DS
# DS
# DS
# DS
# DS

# %% [markdown]
# # **Loops**
# - There may be a situation when you need to execute a block of code several number of times.
# -  Loop == Repeat the block of code.
#
# # **While Loop**
#
# - Repeat the block of code until the condition satisfies.
# - to iterate over a block of code as long as the condition is true.

# %% [markdown]
# ![Screenshot 2024-07-14 125344.png](data:image/png;base64,...)

# %%
x =1

while x < 5:
  print(x)
  x = x+1

print(x)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
x =1

while x <= 5:
  print(x, "DS")
  x = x+1
# Out:
# 1 DS
# 2 DS
# 3 DS
# 4 DS
# 5 DS

# %%
# Write a program, ask the user to enter any 5 values & do sum

x=1
s=0

while x<=5:
  n=eval(input("enter the number:"))
  s=s+n
  x=x+1

print(s)
# Out:
# enter the number:15
# enter the number:15
# enter the number:15
# enter the number:15
# enter the number:15
# 75

# %%
l=[]

n=eval(input("enter the number: "))
l.append(n)
print(l)
# Out:
# enter the number: 15.5
# [15.5]

# %% [markdown]
# # **Write a program, to store 5 values entered by user into a list**

# %%
l=[]

n=eval(input("enter the number: "))
l.append(n)
n=eval(input("enter the number: "))
l.append(n)
n=eval(input("enter the number: "))
l.append(n)
n=eval(input("enter the number: "))
l.append(n)
n=eval(input("enter the number: "))
l.append(n)
print(l)
# Out:
# enter the number: 1
# enter the number: 2
# enter the number: 3
# enter the number: 4
# enter the number: 5
# [1, 2, 3, 4, 5]

# %%
l=[]
x = 1

while x <= 5:
  n=eval(input("enter the number: "))
  l.append(n)
  print(l)
  x += 1
# Out:
# enter the number: 1
# [1]
# enter the number: 2
# [1, 2]
# enter the number: 3
# [1, 2, 3]
# enter the number: 4
# [1, 2, 3, 4]
# enter the number: 5
# [1, 2, 3, 4, 5]

# %% [markdown]
# # **Infinite loop**
# - when we keep while condition as true for all
# - we can stop the infinite loop by two ways
#  - Click on Stop button
#  - Using key word break

# %%
while True:
  #code

# %% [markdown]
# # **write a program, ask the user to any values & store them in a list**

# %%
print("enter your values & once enteries are completed, enter #")

list222=[]

while True:
  n= input("enter the number: ")
  if n=="#":
    break
  else:
    l.append(n)

print(l)
# Out:
# enter your values & once enteries are completed, enter #
