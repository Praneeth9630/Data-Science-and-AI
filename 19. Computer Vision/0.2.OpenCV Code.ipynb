# %% [markdown]
# **opencv installation can be done in 2 ways**
#
# - conda install -c conda-forge opencv
# - pip install opencv-python

# %%
pip install opencv-python
# Out:
# ...
#
# ...

# %%
import cv2

# %%
cv2.__version__
# Out:
# '4.10.0'

# %%
import numpy as np

# %% [markdown]
# # Load/Read Image

# %%
# Load an image using 'imread' specifying the path to image
img = cv2.imread("image_examples\\Modi.jpg",1)             # Here 1 means color image, 0 means black and white image

# %%
print(img)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %% [markdown]
# ![image.png](attachment:f2ac45c2-1033-44a5-b1f2-32cd76ef57aa.png)

# %%
img.shape
# Out:
# (1358, 1500, 3)

# %%
# Load an image using 'imread' specifying the path to image
img = cv2.imread("image_examples\\Modi.jpg",1)

# Display the image
cv2.imshow("PM",img)                         # Here PM is Tab name
cv2.waitKey()                                # 100000 milli secs
cv2.destroyAllWindows()

# %% [markdown]
# ## **Let's take a closer look at how images are stored**

# %%
# Load an image using 'imread' specifying the path to image
img = cv2.imread("image_examples\\Modi.jpg",1)

# %%
print(img)

# %%
type(img)

# %%
img.ndim

# %%
img.shape

# %% [markdown]
# ## **Resize Images**

# %%
img = cv2.imread('Image_examples\\Modi.jpg',1)

resized_image = cv2.resize(img,(679,750))

cv2.imshow('Modi Image',resized_image)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# ## **Convert Colour image to BlackWhite Image**

# %%
img =cv2.imread('image_examples\\Modi.jpg',1)

resized_image = cv2.resize(img,(750,679))

gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

cv2.imshow('Modi Image', gray)

cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# ## **Save Image**

# %%
# Simply use 'imwrite' specificing the file name and the image to be saved
cv2.imwrite("bw.jpg",gray)

# %% [markdown]
# ## **Computer Vision**
#
# - Object Detection as per your requirements
#
# Ex: if you want to detect human face, it detect human face
#
# Ex: if you want to detect mobile, it detect mobile within the given image

# %% [markdown]
# ## **Face Detection using HAAR Cascade Classifiers**

# %%
#apply for on what you want to check
image = cv2.imread('image_examples\\Modi.jpg',1)

image = cv2.resize(image, (679,750))

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)           # As cascade classifier is in 2d array  we need image in 2d so convert the image to grey colour

# %%
#lood the features
face_classifier = cv2. CascadeClassifier('Haarcascades/haarcascade_frontalface_default.xml')

# %%
#Matching the features on given image
faces = face_classifier.detectMultiScale(gray, 1.5, 5)      # Detectmultiscale means detect in my image whether those features are there or not

# %%
faces

# %%
#load the features
face_classifier = cv2. CascadeClassifier('Haarcascades/haarcascade_frontalface_default.xml')

#apply for on what you want to check
image = cv2.imread('image_examples\\Modi.jpg',1)
image = cv2.resize(image,(679,750))
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

#Matching the features on given image
faces = face_classifier.detectMultiScale(gray, 1.05, 5)

if faces is ():
    print("No faces found")

else:
    for (x,y,l,h) in faces:
        cv2.rectangle(image, (x,y), (x+l,y+h),(0,0,255), 1)   # 0,0,255 = BGR & here 1 means thickness of line.

cv2.imshow('Face Detection', image)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # Face & Eye Detection using HAAR Cascade Classifiers in Image

# %%
#load the features
face_classifier = cv2.CascadeClassifier('Haarcascades/haarcascade_frontalface_default.xml')
eye_classifier = cv2.CascadeClassifier('Haarcascades/haarcascade_eye.xml')

#load the image whete yo want to identify the features
img = cv2.imread('image_examples\\modi.jpg',1)
resized_image = cv2.resize(img,(679,750))
gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

#detect
faces = face_classifier.detectMultiScale(gray, 1.05, 5)

if faces is ():
    print("No Face Found")

for (x,y,w,h) in faces:
    cv2.rectangle(resized_image,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = resized_image[y:y+h, x:x+w]
    
    eyes = eye_classifier.detectMultiScale(roi_gray, 1.05, 5)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),1)

cv2.imshow('img',resized_image)
cv2.waitKey()

cv2.destroyAllWindows()

# %% [markdown]
# # Capture a video

# %%
# Doing some Face Recognition with the webcam

import cv2
video = cv2.VideoCapture(0)                                   #0 -- webcam

while True:
    num, frame = video.read()
    #gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    cv2.imshow('Video',frame)
    if cv2.waitKey(1) == ord('q'):
        break

video.release()
cv2.destroyAllWindows ()

# %% [markdown]
# # Face & Eye Detection using HAAR Cascade Classifiers

# %%
# Defining a function that will do the detections
face_cascade = cv2.CascadeClassifier('Haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('Haarcascades/haarcascade_eye.xml')

def detect(gray, frame):
    faces = face_cascade.detectMultiScale(gray, 1.05, 5)
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h),(255,0,0),2)
        roi_gray = gray[y:y+h, x: x+w]
        roi_color = frame[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray, 1.05, 5)
        for (ex, ey, ew, eh) in eyes:
            cv2.rectangle(roi_color, (ex, ey), (ex+ew, ey+eh), (0, 255,0), 2)
    return frame

# Doing some Face Recognition with the webcam
video = cv2.VideoCapture(0)


while True:
    check, frame = video.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    canvas = detect(gray, frame)
    cv2.imshow('Video', frame)
    if cv2.waitKey(1) == ord('q'):
        break

video.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Pedistrian Detection

# %%
import cv2

#Load the features
body_classifier = cv2.CascadeClassifier('Haarcascades\haarcascade_fullbody.xml')

#
cap = cv2.VideoCapture('image_examples\walking.avi')

#detect
while cap.isOpened():
    check, frame = cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    bodies = body_classifier.detectMultiScale(gray, 1.2, 3)

# Extract bounding boxes for any bodies identified
    for (x,y,w,h) in bodies:
        cv2.rectangle(frame, (x, y), (x+w, y+h),(0, 255, 255), 2)
        cv2.imshow('Pedestrians', frame)

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import time

#Load the features
car_classifier = cv2.CascadeClassifier('Haarcascades\haarcascade_car.xml')

# Initiate video capture for video file
cap = cv2. VideoCapture('image_examples/cars.avi')

# detect
while cap.isOpened():
    
    time.sleep(.01)
    check, frame = cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    cars = car_classifier.detectMultiScale(gray, 1.4, 2)
    for (x,y,w,h) in cars:
        cv2.rectangle(frame, (x, y), (x+w, y+h),(0, 255, 255), 2)
        cv2.imshow('Cars', frame)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
